# %%
## import the necessary library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/pokemon.csv")

# %%
df
# Out:
#            name  attack  defense  capture_rate   hp  sp_attack  sp_defense  \
# 0     Bulbasaur      49       49            45   45         65          65
# 1       Ivysaur      62       63            45   60         80          80
# 2      Venusaur     100      123            45   80        122         120
# 3    Charmander      52       43            45   39         60          50
# 4    Charmeleon      64       58            45   58         80          65
# ..          ...     ...      ...           ...  ...        ...         ...
# 795  Celesteela     101      103            25   97        107         101
# 796     Kartana     181      131           255   59         59          31
# 797    Guzzlord     101       53            15  223         97          53
# 798    Necrozma     107      101             3   97        127          89
# 799    Magearna      95      115             3   80        130         115
#
#      speed     type
# 0       45    grass
# 1       60    grass
# ...

# %%
df.drop(["name"], axis = 1, inplace = True)

# %%
df
# Out:
#      attack  defense  capture_rate   hp  sp_attack  sp_defense  speed     type
# 0        49       49            45   45         65          65     45    grass
# 1        62       63            45   60         80          80     60    grass
# 2       100      123            45   80        122         120     80    grass
# 3        52       43            45   39         60          50     65     fire
# 4        64       58            45   58         80          65     80     fire
# ..      ...      ...           ...  ...        ...         ...    ...      ...
# 795     101      103            25   97        107         101     61    steel
# 796     181      131           255   59         59          31    109    grass
# 797     101       53            15  223         97          53     43     dark
# 798     107      101             3   97        127          89     79  psychic
# 799      95      115             3   80        130         115     65    steel
#
# [800 rows x 8 columns]

# %% [markdown]
# 20) Use Pokemon.csv for the question below, remove the ‘name’ column and do not perform any data cleaning or data preprocessing before answering the question. Considering we are having 10 features and 3 classes in the target variable, what is the range of values, components will take in LDA?

# %%
# Assuming 'type' is the target variable and the remaining columns are features
X = df.drop('type', axis=1)
y = df['type']

# Initialize LDA
# The n_components parameter is not set here to show the default behavior
# which is min(n_classes - 1, n_features)
lda = LinearDiscriminantAnalysis()

# Fit LDA to the data
lda.fit(X, y)

# Print the number of components found by LDA
print(f"Number of components in LDA: {lda.n_components_}")
# Out:
# Number of components in LDA: 7

# %% [markdown]
# 21) Use Pokemon.csv for the question below, remove ‘name’ column and do not perform any data cleaning or data preprocessing before answering the question. Consider we are having 8 features and 12 classes in target variable, what is the range of values, components will take in LDA?

# %% [markdown]
# 22) How do you decide the n_components in the LinearDiscriminantAnalaysis
# Correlation coefficient
# variance
# explained_variance_ratio
# variation inflation factor

# %% [markdown]
# Ans
#
# In Linear Discriminant Analysis (LDA), you can decide the number of components (n_components) by looking at the explained_variance_ratio_ attribute after fitting the model. This attribute shows the proportion of variance explained by each component. You would typically choose a number of components that capture a sufficient amount of the total variance, similar to how you might select components in Principal Component Analysis (PCA).
#
# Therefore, the correct option is explained_variance_ratio.

# %% [markdown]
# 23) LDA assumes that the covariance matrices of all classes are equal
# FALSE
# TRUE

# %% [markdown]
# Ans
#
#
# The statement "LDA assumes that the covariance matrices of all classes are equal" is TRUE.
#
# This is one of the key assumptions of standard Linear Discriminant Analysis. If this assumption is violated, Quadratic Discriminant Analysis (QDA) might be a more appropriate method, as QDA does not assume equal covariance matrices for each class.

# %% [markdown]
# 24) What are the methods that are used to to handle non-linearly
# separable data in LDA
#
# Ensemble methods
#
# LLE
#
#
# Kernel LDA
#
# Regressor

# %% [markdown]
# Ans
#
# To handle non-linearly separable data in LDA, Kernel LDA is used.
#
# Kernel LDA is an extension of LDA that uses the kernel trick to implicitly map the data into a higher-dimensional space where it might be linearly separable, similar to how Kernel PCA works. The other options listed are not typically used for this purpose in the context of LDA.

# %% [markdown]
# 25) On what basis the features are constructed in LDA
#
# minimizes the differences between classes and maximizes the variations within each class.
#
# minimizes the differences between classes and minimizes the variations within each class.
#
# maximizes the differences between classes and maximizes the variations within each class.
#
# maximizes the differences between classes and minimizes the variations within each class.

# %% [markdown]
# Ans
#
# In Linear Discriminant Analysis (LDA), the features are constructed on the basis of maximizing the differences between classes and minimizing the variations within each class.
#
# LDA seeks to find linear combinations of the original features that best separate the different classes. It achieves this by maximizing the ratio of between-class variance to within-class variance.

# %% [markdown]
# 26) Use Pokemon.csv for the question below, remove ‘name’ column and do not perform any data cleaning or data preprocessing before answering the question. Which of the dominant independent features that significantly influences the separability of the class fighting in LDA preprojection post performing below operations? Store column type (Target variable) as y Store Remaining columns as X Normalize the X and get X_norm using normalize in sklearn.preprocessing Apply LDA with n_components as 5 Display LDA coefficients

# %%
from sklearn.preprocessing import normalize
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
import pandas as pd

# Assuming 'type' is the target variable and the remaining columns are features
X = df.drop('type', axis=1)
y = df['type']

# Normalize the features
X_norm = normalize(X)

# Convert normalized features back to a DataFrame for easier analysis with column names
X_norm_df = pd.DataFrame(X_norm, columns=X.columns)

display(X_norm_df.head())
# Out:
#      attack   defense  capture_rate        hp  sp_attack  sp_defense     speed
# 0  0.352463  0.352463      0.323691  0.323691   0.467553    0.467553  0.323691
# 1  0.358928  0.364717      0.260512  0.347349   0.463132    0.463132  0.347349
# 2  0.380039  0.467448      0.171017  0.304031   0.463647    0.456046  0.304031
# 3  0.383099  0.316794      0.331528  0.287324   0.442038    0.368365  0.478874
# 4  0.370283  0.335569      0.260355  0.335569   0.462853    0.376068  0.462853

# %%
# Apply LDA with n_components as 5
lda = LinearDiscriminantAnalysis(n_components=5)

# Fit LDA to the normalized data
lda.fit(X_norm_df, y)

# Display LDA coefficients
# The coefficients are stored in lda.coef_
# To understand the influence of each feature, we can look at the absolute values of the coefficients
# for each component and each class. However, the question asks about the influence on the
# separability of the 'fighting' class specifically. We can examine the coefficients associated
# with the 'fighting' class in the LDA model.

# Get the index of the 'fighting' class
fighting_class_index = lda.classes_.tolist().index('fighting')

print(f"LDA Coefficients for 'fighting' class:")
# lda.coef_ has shape (n_classes, n_features)
# We are interested in the row corresponding to the 'fighting' class
fighting_coefficients = lda.coef_[fighting_class_index, :]

# Create a pandas Series for better visualization with feature names
fighting_coefficients_series = pd.Series(fighting_coefficients, index=X.columns)

# Display the coefficients, sorted by absolute value to see dominant features
print(fighting_coefficients_series.abs().sort_values(ascending=False))
# Out:
# LDA Coefficients for 'fighting' class:
# attack          13.209665
# sp_attack        8.995456
# sp_defense       4.863307
# defense          4.528528
# capture_rate     2.655604
# hp               2.405415
# speed            0.428766
# dtype: float64

# %% [markdown]
# 27) Use Pokemon.csv for the question below, remove ‘name’ column and do not perform any data cleaning or data preprocessing before answering the question. Using the LDA coefficients obtained from question 8 , analyze the coefficient magnitudes and their influences on the separability of the ‘bug’ class. Choose the appropriate description that characterizes the magnitude and separability relationship
# High magnitude and Linearly separable
# Low magnitude and Not Linearly separable
# Low magnitude and Linearly separable
# High magnitude and Not Linearly separable

# %% [markdown]
# Based on the LDA coefficients, a high magnitude coefficient for a feature for a specific class indicates that this feature is important in separating that class from the others. Therefore, a High magnitude generally corresponds to features that contribute more to the Linearly separable nature of the class from others in the reduced-dimensional space.
#
# Considering this, the appropriate description that characterizes the magnitude and separability relationship is:
#
# High magnitude and Linearly separable
